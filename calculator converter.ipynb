# %%
weight=float(input("Enter Your Weight"))
unit=input("Kilograms or Pounds(kgs or labs)? :")
if unit == "K" :
    weight = weight*2.205
    unit = "Lbs."
elif unit == "L":
    weight == weight/2.205
    unit = "Kgs."
else:
    print(f"{unit} doesn't valid ")
print(f"Your weight is :{weight} {unit}")
# Out:
# Enter Your Weight 48
# Kilograms or Pounds(kgs or labs)? : K
# Your weight is :105.84 Lbs.
