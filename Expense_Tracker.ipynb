# %%
# %pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#      ---------------------------------------- 52.8/52.8 kB 2.7 MB/s eta 0:00:00
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ---------------------------------------- 0.0/116.4 kB ? eta -:--:--
#      -------------------------------------- 116.4/116.4 kB 3.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/8.1 MB 17.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.2/8.1 MB 22.9 MB/s eta 0:00:01
#    --------------- ------------------------ 3.1/8.1 MB 22.2 MB/s eta 0:00:01
#    ------------------ --------------------- 3.7/8.1 MB 19.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.0/8.1 MB 17.1 MB/s eta 0:00:01
#    -------------------- ------------------- 4.3/8.1 MB 16.0 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# Load existing data
try:
    df = pd.read_csv('expenses.csv')
except FileNotFoundError:
    df = pd.DataFrame(columns=["Date", "Category", "Amount", "Description"])

# %%
date= input("Enter date (YYYY-MM-DD): ") or datetime.today().strftime('%Y-%m-%d')
category = input("Enter category (eg, food , travel, bills): ")
amt = float(input("Enter Amount"))
desc=input("Enter Description of expenses")

new_expense = pd.DataFrame([[date, category, amt, desc]], columns=df.columns)
df = pd.concat([df, new_expense], ignore_index=True)


# Save to CSV
df.to_csv('expenses.csv', index=False)
print("Expense added!")
# Out:
# Enter date (YYYY-MM-DD):  2025
# Enter category (eg, food , travel, bills):  travel
# Enter Amount 500
# Enter Description of expenses date
# Expense added!
