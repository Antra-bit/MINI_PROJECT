# %%
# Initialize scores
you = 0

# Question 1
print("Q1) What house is Harry Potter sorted into?")
print("1) Ravenclaw")
print("2) Gryffindor")
print("3) Slytherin")
print("4) Hufflepuff")
answer1 = int(input("Enter 1, 2, 3, 4: "))

if answer1 == 1:
    you+=0
elif answer1 == 2:
    you+=2
elif answer1 == 3:
    you+=0
elif answer1 == 4:
    you+=0
else:
    print("Wrong input.")
# Out:
# Q1) What house is Harry Potter sorted into?
# 1) Ravenclaw
# 2) Gryffindor
# 3) Slytherin
# 4) Hufflepuff

# %%
# Question 2
print("\nQ2) What is the name of Harry’s pet owl?:")
print("1) Crookshanks")
print("2)  Fang")
print("3) Hedwig")
print("4)  Scabbers")
answer2 = int(input("Enter 1, 2, 3 or 4: "))

if answer2 == 1:
     you+=0
elif answer2 == 2:
     you+=0
elif answer2 == 3:
     you+=2
elif answer2 == 4:
     you+=0
else:
    print("Wrong input.")

# %%
# Question 3
print("\nQ3) Which position does Harry play on the Gryffindor Quidditch team?")
print("1)  Beater")
print("2) Chaser")
print("3) Seeker")
print("4) Keeper")
answer3 = int(input("Enter 1, 2, 3 or 4: "))

if answer3 == 1:
    you+=0
elif answer3 == 2:
    you+=0
elif answer3 == 3:
    you+=2
elif answer3 == 4:
    you+=0
else:
    print("Wrong input.")

# %%
# Question 4
print("\nQ4) Who becomes the master of the Elder Wand after Dumbledore?")
print("1)  Voldemort")
print("2)  Draco Malfoy")
print("3) Snape")
print("4) Harry Potter")
answer4 = int(input("Enter 1, 2, 3 or 4: "))

if answer4 == 1:
    you+=0
elif answer4 == 2:
    you+=4
elif answer4 == 3:
    you+=4
elif answer4 == 4:
    you+=0
else:
    print("Wrong input.")


# Final scores
print("\n--- Final Scores ---")
print("Your Score out of 10:", you)
